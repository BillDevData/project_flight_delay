# %%
from src.predict import predict_delay

payload = {
    "aerolinea": "F9",
    "origen": "Austin, TX",
    "destino": "Albuquerque, NM",
    "fecha_partida": "2026-02-14T18:30:00",
    "distancia_km": 619
}

print(predict_delay(payload))
# Out:
# {'prevision': 'Retrasado', 'probabilidad': 0.67}
